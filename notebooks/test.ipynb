# %%
import pandas as pd
import numpy as np

# %%
year = ['1896', '1896', '1896']
Country = ['Afghanistan', 'Algeria', 'Afghanistan']
Medal = ['Gold', 'Silver', 'Gold']
Number = ['5', '3', '2']

# %%
dict = {'Year': year, 'Country':Country, 'Medal':Medal, 'Number':Number}

# %%
df = pd.DataFrame(dict)

# %%
data = {'Year': ['1896', '1896', '1896'],
        'Country':['Afghanistan', 'Algeria', 'Afghanistan'],
        'Medal':['Gold', 'Silver', 'Gold'],
        'Number':[5, 3, 2]}

# %%
df = pd.DataFrame(data)
df
# Out:
#    Year      Country   Medal  Number
# 0  1896  Afghanistan    Gold       5
# 1  1896      Algeria  Silver       3
# 2  1896  Afghanistan    Gold       2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Year     3 non-null      object
#  1   Country  3 non-null      object
#  2   Medal    3 non-null      object
#  3   Number   3 non-null      int64
# dtypes: int64(1), object(3)
# memory usage: 228.0+ bytes

# %%
df.groupby(['Country','Medal'])['Number'].count()
# Out:
# Country      Medal
# Afghanistan  Gold      2
# Algeria      Silver    1
# Name: Number, dtype: int64

# %%
# !pip install accelerate==0.21.0 transformers==4.31.0 tokenizers==0.13.3
# !pip install bitsandbytes==0.41.3 einops==0.6.1
# !pip install xformers==0.0.22.post7
# !pip install langchain==0.1.4
# !pip install faiss-gpu==1.7.1.post3
# !pip install sentence_transformers
# Out:
# ...
#   Obtaining dependency information for accelerate==0.21.0 from https://files.pythonhosted.org/packages/70/f9/c381bcdd0c3829d723aa14eec8e75c6c377b4ca61ec68b8093d9f35fc7a7/accelerate-0.21.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for transformers==4.31.0 from https://files.pythonhosted.org/packages/21/02/ae8e595f45b6c8edee07913892b3b41f5f5f273962ad98851dc6a564bbb9/transformers-4.31.0-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/116.9 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/116.9 kB ? eta -:--:--
#      ------------ ------------------------ 41.0/116.9 kB 653.6 kB/s eta 0:00:01
#      -------------------------------------- 116.9/116.9 kB 1.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/314.9 kB ? eta -:--:--
#      -------------- ----------------------- 122.9/314.9 kB 3.6 MB/s eta 0:00:01
#      -------------------------------------- 314.9/314.9 kB 3.9 MB/s eta 0:00:00
# ...

# %%
from torch import cuda, bfloat16
import transformers

model_id = 'meta-llama/Llama-2-7b-chat-hf'

device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'

# set quantization configuration to load large model with less GPU memory
# this requires the `bitsandbytes` library
bnb_config = transformers.BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=bfloat16
)

hf_auth = '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'
model_config = transformers.AutoConfig.from_pretrained(
    model_id,
    use_auth_token=hf_auth
)

model = transformers.AutoModelForCausalLM.from_pretrained(
    model_id,
    trust_remote_code=True,
    config=model_config,
    quantization_config=bnb_config,
    device_map='auto',
    use_auth_token=hf_auth
)

# enable evaluation mode to allow model inference
model.eval()

print(f"Model loaded on {device}")
# Out:
# C:\Users\Hammer\PycharmProjects\redcell\.redenv\Lib\site-packages\transformers\models\auto\configuration_auto.py:919: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# C:\Users\Hammer\PycharmProjects\redcell\.redenv\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# ...
